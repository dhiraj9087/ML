# %%
import requests
from bs4 import BeautifulSoup

college_name = 'PIMPRI CHINCHWAD COLLEGE OF ENGINEERING'

# Search for the college on Google
search_url = f'https://www.google.com/search?q={college_name}&rlz=1C1GCEU_enUS832US832&oq={college_name}'
response = requests.get(search_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract the URL of the first search result
result_div = soup.find('div', {'class': 'g'})
result_link = result_div.find('a')['href']

# Print the URL of the first search result
print(f"The official website of '{college_name}' is: {result_link}")

# %%
import requests
from bs4 import BeautifulSoup

college_name = 'COLLEGE OF ENGINEERING PUNE'

# Search for the college on Google
search_url = f'https://www.google.com/search?q={college_name}&rlz=1C1GCEU_enUS832US832&oq={college_name}'
response = requests.get(search_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract the URL of the first search result (if it exists)
result_div = soup.find('div', {'class': 'g'})
if result_div is not None:
    result_link = result_div.find('a')['href']
    print(f"The official website of '{college_name}' is: {result_link}")
else:
    print(f"No search results found for '{college_name}'")
# Out:
# No search results found for 'COLLEGE OF ENGINEERING PUNE'

# %%
import requests

college_name = 'COLLEGE OF ENGINEERING PUNE'
api_url = f'https://api.data.gov/ed/collegescorecard/v1/schools.json?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&fields=school.name,school.school_url&school.name={college_name}'

response = requests.get(api_url)

if response.status_code == 200:
    data = response.json()
    if data['metadata']['total'] > 0:
        college_url = data['results'][0]['school.school_url']
        print(f"The official website of '{college_name}' is: {college_url}")
    else:
        print(f"No data found for '{college_name}'")
else:
    print("API request failed")
# Out:
# API request failed

# %%
import requests
from bs4 import BeautifulSoup

college_name = 'COLLEGE OF ENGINEERING PUNE'

# Search for the college on Google
search_url = f'https://www.google.com/search?q={college_name}&rlz=1C1GCEU_enUS832US832&oq={college_name}'
response = requests.get(search_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract the URL of the first search result (if it exists)
print(soup.find('div'))
result_div = soup.find('div', {'class': 'g'})
if result_div:
    result_link = result_div.find('a')['href']
    print(f"The official website of '{college_name}' is: {result_link}")
else:
    print(f"No search results found for '{college_name}'")
# Out:
# <div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwiyjfz4geb9AhUDkOYKHZXwDnsQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>
# No search results found for 'COLLEGE OF ENGINEERING PUNE'

# %% [markdown]
# ## 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

# %%
questions = [
    {
        "id": 1,
        "question": "What is the Full Form Of RAM?",
        "answer": "Random Access Memory",
        "options": [
            "Run Accept Memory",
            "Random All Memory",
            "Random Access Memory",
            "None of these"
        ]
    },
    {
        "id": 2,
        "question": "What is the Full-Form of CPU?",
        "answer": "Central Processing Unit",
        "options": [
            "Central Program Unit",
            "Central Processing Unit",
            "Central Preload Unit",
            "None of these"
        ]
    },
    {
        "id": 3,
        "question": "What is the Full-Form of E-mail",
        "answer": "Electronic Mail",
        "options": [
            "Electronic Mail",
            "Electric Mail",
            "Engine Mail",
            "None of these"
        ]
    },
    {
        "id": 4,
        "question": "'DB' in computer means?",
        "answer": "DataBase",
        "options": [
            "Double Byte",
            "Data Block",
            "DataBase",
            "None of these"
        ]
    },
    {
        "id": 5,
        "question": "What is FMD?",
        "answer": "Fluorescent Multi-Layer Disc",
        "options": [
            "Fluorescent Multi-Layer Disc",
            "Flash Media Driver",
            "Fast-Ethernet Measuring Device",
            "None of these"
        ]
    },
    {
        "id": 6,
        "question": "How many bits is a byte?",
        "answer": "8",
        "options": [
            "32",
            "16",
            "8",
            "64"
        ]
    },
    {
        "id": 7,
        "question": "A JPG stands for:",
        "answer": "A format for an image file",
        "options": [
            "A format for an image file",
            "A Jumper Programmed Graphic",
            "A type of hard disk",
            "A unit of measure for memory"
        ]
    },
    {
        "id": 8,
        "question": "Which was an early mainframe computer?",
        "answer": "ENIAC",
        "options": [
            "ENIAC",
            "EDVAC",
            "UNIC",
            "ABACUS"
        ]
    },
    {
        "id": 9,
        "question": "Main circuit board in a computer is:",
        "answer": "Mother board",
        "options": [
            "Harddisk",
            "Mother board",
            "Microprocessor",
            "None of these"
        ]
    },
    {
        "id": 10,
        "question": "ISP stands for:",
        "answer": "Internet Service Provider",
        "options": [
            "Internet Survey Period",
            "Integrated Service Provider",
            "Internet Security Protocol",
            "Internet Service Provider"

        ]
    },
]

question_count = 0
points = 0

def show(count):
    global question_count
    question = questions[count]
    first, second, third, fourth = question["options"]
    print(f"Q{count + 1}. {question['question']}")
    print(f"1. {first}")
    print(f"2. {second}")
    print(f"3. {third}")
    print(f"4. {fourth}")
    toggleActive()

def toggleActive():
    option = input("Select an option (1-4): ")
