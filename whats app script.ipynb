# %%
# Out:
# ...
#      |████████████████████████████████| 59 kB 5.9 MB/s eta 0:00:011
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 58 kB 5.2 MB/s eta 0:00:011
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36614 sha256=616f8327eae79d182c0d9d2dfac8f68968cd352ca9392859a23b37a3c35ffacc
#   Stored in directory: /Users/dhirajmarathe/Library/Caches/pip/wheels/d8/97/e4/d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
# ...
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11081 sha256=4e6f86a833137c4293f21afed4856ccf6e8be4f3cabc0d3d49ec7c6b7a7ac628
#   Stored in directory: /Users/dhirajmarathe/Library/Caches/pip/wheels/44/ab/20/423c3a444793767e4e41f8377bc902f77bee212e68dcce85a5
# ...

# %%
# import random
# # @python.coder
# import pyautogui as pg
# import time
# animal=('this is python script','do yo like it?')
# time.sleep(8)
# for i in range(25):
#     a=random.choice(animal)
#     pg.write(a)
#     pg.press('enter')
