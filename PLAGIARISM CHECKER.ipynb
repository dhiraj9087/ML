# %%
import os

# %%
# !pip install numpy scipy
# Out:
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: scipy in ./opt/anaconda3/lib/python3.9/site-packages (1.7.3)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./opt/anaconda3/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: scipy>=1.5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: joblib>=1.1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.3.1)

# %%
import sklearn

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./opt/anaconda3/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: scipy>=1.5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: joblib>=1.1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/__init__.py:8, in <module>
#       1 """
#       2 The :mod:`sklearn.feature_extraction` module deals with feature extraction
#       3 from raw data. It currently includes methods to extract features from text and
#       4 images.
#       5 """
#       7 from . import text
# ----> 8 from ._dict_vectorizer import DictVectorizer
#       9 from ._hash import FeatureHasher
#      10 from .image import grid_to_graph, img_to_graph
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:5, in <module>
#       1 # Authors: Lars Buitinck
#       2 #          Dan Blanchard <dblanchard@ets.org>
#       3 # License: BSD 3 clause
# ----> 5 from array import array
#       6 from collections.abc import Iterable, Mapping
#       7 from numbers import Number
#
# ImportError: cannot import name 'array' from 'array' (/Users/dhirajmarathe/array.py)

# %%
jupyter --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 jupyter --version
#
# NameError: name 'jupyter' is not defined

# %%
import notebook
print(notebook.__version__)
# Out:
# 6.4.8

# %%
conda install jupyter
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::holoviews==1.14.8=pyhd3eb1b0_0
#   - defaults/osx-64::notebook==6.4.8=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/noarch::dask==2022.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda==2022.05=py39_0
#   - defaults/noarch::datashader==0.13.0=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_server==1.13.5=pyhd3eb1b0_0
#   - defaults/noarch::sphinx==4.4.0=pyhd3eb1b0_0
#   - defaults/noarch::numpydoc==1.2=pyhd3eb1b0_0
#   - defaults/noarch::anaconda-project==0.10.2=pyhd3eb1b0_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::conda-build==3.21.9=py39hecd8cb5_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::nbconvert==6.4.4=py39hecd8cb5_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.2=py39hecd8cb5_0
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::hvplot==0.7.3=pyhd3eb1b0_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab==3.3.2=pyhd3eb1b0_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py39hecd8cb5_0
#   - defaults/noarch::distributed==2022.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::panel==0.13.0=py39hecd8cb5_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::holoviews==1.14.8=pyhd3eb1b0_0
#   - defaults/osx-64::notebook==6.4.8=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/noarch::dask==2022.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda==2022.05=py39_0
#   - defaults/noarch::datashader==0.13.0=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_server==1.13.5=pyhd3eb1b0_0
#   - defaults/noarch::sphinx==4.4.0=pyhd3eb1b0_0
#   - defaults/noarch::numpydoc==1.2=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda-navigator==2.3.2=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.2=pyhd3eb1b0_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::conda-build==3.21.9=py39hecd8cb5_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::nbconvert==6.4.4=py39hecd8cb5_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.2=py39hecd8cb5_0
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::hvplot==0.7.3=pyhd3eb1b0_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab==3.3.2=pyhd3eb1b0_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py39hecd8cb5_0
#   - defaults/noarch::distributed==2022.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::panel==0.13.0=py39hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/dhirajmarathe/opt/anaconda3
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.10  |           py39_2          69 KB
#     anaconda-custom            |           py39_2          13 KB
#     anaconda-navigator-2.4.2   |   py39hecd8cb5_0         6.8 MB
#     boltons-23.0.0             |   py39hecd8cb5_0         423 KB
#     ca-certificates-2023.05.30 |       hecd8cb5_0         121 KB
#     certifi-2023.5.7           |   py39hecd8cb5_0         153 KB
#     conda-23.3.1               |   py39hecd8cb5_0         962 KB
#     flask-2.2.2                |   py39hecd8cb5_0         148 KB
#     jinja2-3.1.2               |   py39hecd8cb5_0         215 KB
#     jsonpatch-1.32             |     pyhd3eb1b0_0          15 KB
#     jsonpointer-2.1            |     pyhd3eb1b0_0           9 KB
#     markupsafe-2.1.1           |   py39hca72f7f_0          21 KB
#     openssl-1.1.1u             |       hca72f7f_0         3.4 MB
#     werkzeug-2.2.3             |   py39hecd8cb5_0         343 KB
#     ------------------------------------------------------------
#                                            Total:        12.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2022.10-py39_2
#   boltons            pkgs/main/osx-64::boltons-23.0.0-py39hecd8cb5_0
#   flask              pkgs/main/osx-64::flask-2.2.2-py39hecd8cb5_0
#   jinja2             pkgs/main/osx-64::jinja2-3.1.2-py39hecd8cb5_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd3eb1b0_0
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyhd3eb1b0_0
#   markupsafe         pkgs/main/osx-64::markupsafe-2.1.1-py39hca72f7f_0
#   werkzeug           pkgs/main/osx-64::werkzeug-2.2.3-py39hecd8cb5_0
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                   2.3.2-py39hecd8cb5_0 --> 2.4.2-py39hecd8cb5_0
#   ca-certificates                      2022.3.29-hecd8cb5_1 --> 2023.05.30-hecd8cb5_0
#   certifi                          2021.10.8-py39hecd8cb5_2 --> 2023.5.7-py39hecd8cb5_0
#   conda                              22.11.1-py39hecd8cb5_3 --> 23.3.1-py39hecd8cb5_0
#   openssl                                 1.1.1n-hca72f7f_0 --> 1.1.1u-hca72f7f_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.05-py39_0 --> custom-py39_2
#
#
#
# Downloading and Extracting Packages
# jinja2-3.1.2         | 215 KB    |                                       |   0%
# anaconda-custom      | 13 KB     |                                       |   0%
#
# openssl-1.1.1u       | 3.4 MB    |                                       |   0%
#
#
# werkzeug-2.2.3       | 343 KB    |                                       |   0%
#
#
#
# jsonpointer-2.1      | 9 KB      |                                       |   0%
#
#
#
#
# conda-23.3.1         | 962 KB    |                                       |   0%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    |                                       |   0%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    |                                       |   0%
#
#
#
#
#
#
#
# flask-2.2.2          | 148 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    |                                       |   0%
#
#
#
# jsonpointer-2.1      | 9 KB      | ##################################### | 100%
#
# openssl-1.1.1u       | 3.4 MB    | 1                                     |   0%
# anaconda-custom      | 13 KB     | ##################################### | 100%
#
#
# jinja2-3.1.2         | 215 KB    | ##7                                   |   7%
#
#
#
#
# conda-23.3.1         | 962 KB    | 6                                     |   2%
#
# openssl-1.1.1u       | 3.4 MB    | 8                                     |   2%
#
#
#
# jsonpointer-2.1      | 9 KB      | ##################################### | 100%
# anaconda-custom      | 13 KB     | ##################################### | 100%
#
#
# jinja2-3.1.2         | 215 KB    | ###########                           |  30%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    | ###8                                  |  10%
#
#
#
#
# conda-23.3.1         | 962 KB    | #8                                    |   5%
#
# openssl-1.1.1u       | 3.4 MB    | #3                                    |   4%
#
#
# werkzeug-2.2.3       | 343 KB    | ###############5                      |  42%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    | ###########6                          |  31%
#
#
#
#
# jinja2-3.1.2         | 215 KB    | ######################                |  60%
#
# openssl-1.1.1u       | 3.4 MB    | ##                                    |   6%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    | #######################2              |  63%
#
#
# werkzeug-2.2.3       | 343 KB    | ########################1             |  65%
#
# openssl-1.1.1u       | 3.4 MB    | ##9                                   |   8%
#
#
#
#
# conda-23.3.1         | 962 KB    | ######7                               |  18% [[[1 2 3]
#   [2 3 4]]
#
#  [[4 5 6]
#   [5 6 7]]]
# jinja2-3.1.2         | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    |                                       |   0%
#
#
#
#
# conda-23.3.1         | 962 KB    | ##########4                           |  28%
#
# openssl-1.1.1u       | 3.4 MB    | ####8                                 |  13%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    | ##################################### | 100%
#
#
#
#
#
# certifi-2023.5.7     | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# flask-2.2.2          | 148 KB    | ####                                  |  11%
#
#
# werkzeug-2.2.3       | 343 KB    | ##################################### | 100%
#
#
# werkzeug-2.2.3       | 343 KB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | 5                                     |   2%
#
#
#
#
# conda-23.3.1         | 962 KB    | ##############1                       |  38%
#
# openssl-1.1.1u       | 3.4 MB    | ######                                |  16%
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | 9                                     |   3%
#
# openssl-1.1.1u       | 3.4 MB    | #######                               |  19%
#
#
#
#
#
#
#
# flask-2.2.2          | 148 KB    | ################                      |  43%
#
#
#
#
# conda-23.3.1         | 962 KB    | #################2                    |  47%
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #2                                    |   3%
#
# openssl-1.1.1u       | 3.4 MB    | ########                              |  22%
#
#
#
#
#
#
#
# flask-2.2.2          | 148 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# flask-2.2.2          | 148 KB    | ##################################### | 100%
#
# openssl-1.1.1u       | 3.4 MB    | #########8                            |  27%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | ############################1         |  76%
#
#
#
#
# conda-23.3.1         | 962 KB    | ####################2                 |  55%
#
# openssl-1.1.1u       | 3.4 MB    | ###########                           |  30%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | ##################################### | 100%
#
#
#
#
# conda-23.3.1         | 962 KB    | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ########5                             |  23%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##7                                   |   7%
#
# openssl-1.1.1u       | 3.4 MB    | ############9                         |  35%
#
#
#
#
# conda-23.3.1         | 962 KB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ########################4             |  66%
#
# openssl-1.1.1u       | 3.4 MB    | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    | #3                                    |   4%
#
#
#
#
# conda-23.3.1         | 962 KB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    | ###########1                          |  30%
#
# openssl-1.1.1u       | 3.4 MB    | ################                      |  43%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ####5                                 |  12%
#
#
#
#
# conda-23.3.1         | 962 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    | ##########################5           |  72%
#
# openssl-1.1.1u       | 3.4 MB    | ###################1                  |  52%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #####5                                |  15%
#
# openssl-1.1.1u       | 3.4 MB    | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 423 KB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ######3                               |  17%
#
# openssl-1.1.1u       | 3.4 MB    | #######################               |  62%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #######                               |  19%
#
# openssl-1.1.1u       | 3.4 MB    | ########################9             |  68%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #######8                              |  21%
#
# openssl-1.1.1u       | 3.4 MB    | ##########################8           |  73%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ########6                             |  23%
#
# openssl-1.1.1u       | 3.4 MB    | ############################9         |  78%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #########4                            |  25%
#
# openssl-1.1.1u       | 3.4 MB    | ##############################8       |  83%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##########1                           |  27%
# openssl-1.1.1u       | 3.4 MB    | #################################2    |  90%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##########9                           |  30%
#
# openssl-1.1.1u       | 3.4 MB    | ###################################1  |  95%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###########6                          |  32%
#
# openssl-1.1.1u       | 3.4 MB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ############9                         |  35%
#
# openssl-1.1.1u       | 3.4 MB    | ##################################### | 100%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #############9                        |  38%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##############9                       |  40%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###############9                      |  43%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ################8                     |  46%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #################7                    |  48%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##################6                   |  50%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###################8                  |  54%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ####################7                 |  56%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ######################1               |  60%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #######################2              |  63%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ########################3             |  66%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #########################6            |  69%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###########################1          |  73%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ############################3         |  77%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #############################6        |  80%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ##############################9       |  84%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ################################4     |  88%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | #################################8    |  91%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ###################################3  |  95%
#
#
#
#
#
#
# anaconda-navigator-2 | 6.8 MB    | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
